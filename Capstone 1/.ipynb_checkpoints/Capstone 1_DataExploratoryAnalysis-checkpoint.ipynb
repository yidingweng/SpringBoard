# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import seaborn as sns

# %%
with open('data/Seasons_Stats_cleansed.csv') as csvfile:
    reader1 = csv.reader(csvfile)
data = pd.read_csv('data/Seasons_Stats_cleansed.csv',sep='\t')

# %%
data.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year               Player Pos  Age   Tm   G  \
# 0        3218          5010  1978  Kareem Abdul-Jabbar   C   30  LAL  62
# 1        3219          5011  1978        Tom Abernethy  SF   23  LAL  73
# 2        3220          5012  1978          Alvan Adams   C   23  PHO  70
# 3        3221          5013  1978         Lucius Allen  PG   30  KCK  77
# 4        3222          5017  1978       Tate Armstrong  SG   22  CHI  66
#
#        MP       PER   ...         DRB        TRB       AST       STL  \
# 0  2265.0  0.464106   ...    9.774834  12.731126  4.275497  1.637086
# 1  1317.0  0.426424   ...    4.373576   7.243736  2.760820  1.503417
# 2  1914.0  0.332915   ...    7.655172  10.626959  4.231975  1.617555
# 3  2147.0  0.223009   ...    2.733116   3.839776  6.036330  1.559385
# 4   716.0  0.558101   ...    2.212291   3.418994  3.720670  1.156425
#
#         BLK       TOV        PF        PTS  height  weight
# 0  2.940397  3.305960  2.892715  25.430464   218.0   102.0
# 1  0.601367  1.366743  3.334852  13.476082   201.0    99.0
# 2  1.184953  4.401254  4.551724  20.351097   206.0    95.0
# 3  0.469492  3.638565  3.018165  15.426176   188.0    79.0
# 4  0.000000  2.916201  2.111732  14.279330   190.0    79.0
#
# [5 rows x 53 columns]

# %%
pre90s = data[~(data['Year']>1989)]

# %%
print(pre90s["Pos"].value_counts())
# Out:
# SF    640
# PF    631
# C     626
# SG    602
# PG    574
# Name: Pos, dtype: int64

# %%
_90s = data[~(data['Year']<1990) & ~(data['Year']>1999)]

# %%
print(_90s["Pos"].value_counts())
# Out:
# PF    655
# PG    608
# SF    587
# SG    560
# C     558
# Name: Pos, dtype: int64

# %%
_00s = data[~(data['Year']<2000) & ~(data['Year']>2009)]

# %%
_00s.sample(10)
# Out:
#       Unnamed: 0  Unnamed: 0.1  Year          Player Pos  Age   Tm   G  \
# 6188        9427         14707  2000     Damon Jones  PG   23  TOT  55
# 9021       12314         19444  2009  Tyson Chandler   C   26  NOH  45
# 9079       12375         19549  2009   Danny Granger  SF   25  IND  67
# 6963       10207         15965  2002   Hedo Turkoglu  SF   22  SAC  80
# 8607       11892         18708  2007    Chris Webber  PF   33  TOT  61
# 8040       11314         17772  2006      Brian Cook  PF   25  LAL  81
# 8443       11725         18435  2007    Juwan Howard  PF   33  HOU  80
# 6817       10060         15750  2002    Popeye Jones  PF   31  WAS  79
# 7702       10962         17181  2005     Kelvin Cato   C   30  ORL  62
# 8620       11905         18731  2007     Mo Williams  PG   24  MIL  68
#
#           MP       PER   ...         DRB        TRB       AST       STL  \
# 6188   612.0  0.770588   ...    2.529412   3.235294  5.647059  1.058824
# 9021  1445.0  0.333841   ...    5.730104   9.791003  0.548097  0.373702
# 9079  2424.0  0.323762   ...    4.336634   5.064356  2.717822  1.024752
# 6963  1970.0  0.259492   ...    5.482234   6.633503  2.978680  1.041624
# 8607  1821.0  0.316310   ...    6.187809   8.639209  3.716639  1.186161
# 8040  1535.0  0.365863   ...    4.362215   6.426059  1.735505  0.867752
# 8443  2123.0  0.217051   ...    5.629769   7.969854  2.221385  0.491757
# 6817  1920.0  0.270000   ...    6.468750  10.837500  2.381250  0.937500
# 7702  1525.0  0.351738   ...    7.412459   9.820328  0.944262  1.298361
# 8620  2472.0  0.237379   ...    4.004854   4.791262  6.058252  1.237864
#
#            BLK       TOV        PF        PTS  height  weight
# 6188  0.058824  2.352941  2.000000  13.705882   190.0    83.0
# 9021  1.395156  1.743945  3.587543   9.890657   216.0   108.0
# 9079  1.440594  2.450495  3.074257  25.663366   206.0   100.0
# 6963  0.566497  1.480203  3.362437  14.802030   208.0    99.0
# 8607  0.810544  2.115321  2.827018  13.522241   206.0   111.0
# 8040  0.750489  1.430619  4.807818  15.056678   206.0   106.0
# 8443  0.135657  1.899199  3.476213  13.107866   206.0   108.0
# 6817  0.356250  1.650000  3.918750  10.387500   203.0   113.0
# 7702  1.935738  1.510820  4.013115  10.198033   211.0   115.0
# 8620  0.087379  2.956311  2.927184  17.097087   203.0   102.0
#
# [10 rows x 53 columns]

# %%
print(_00s["Pos"].value_counts())
# Out:
# PF    669
# PG    667
# C     663
# SG    637
# SF    613
# Name: Pos, dtype: int64

# %%
_10s = data[~(data['Year']<2010)]

# %%
print(_10s["Pos"].value_counts())
# Out:
# SG    580
# PF    569
# PG    549
# SF    543
# C     508
# Name: Pos, dtype: int64

# %%
for stat in [("PTS","Points")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("PTS","Points")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("PTS","Points")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("PTS","Points")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("AST","Assists")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("AST","Assists")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("AST","Assists")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("AST","Assists")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("TRB","Total Rebounds")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("TRB","Total Rebounds")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("TRB","Total Rebounds")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("TRB","Total Rebounds")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("STL","Steals")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("STL","Steals")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("STL","Steals")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("STL","Steals")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("BLK","Blocks")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("BLK","Blocks")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("BLK","Blocks")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("BLK","Blocks")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("PF","Personal Fouls")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("PF","Personal Fouls")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("PF","Personal Fouls")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("PF","Personal Fouls")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("height","height")]:
    sns.violinplot(y="Pos", x=stat[0], data=pre90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
    
for stat in [("height","height")]:
    sns.violinplot(y="Pos", x=stat[0], data=_90s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("height","height")]:
    sns.violinplot(y="Pos", x=stat[0], data=_00s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()

for stat in [("height","height")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"saddlebrown", "SF":"yellowgreen", "C":"darkmagenta"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
for stat in [("PTS","Points"), ("AST","Assists"), ("TRB","Total Rebounds"), ("STL","Steals"),
             ("BLK","Blocks"),("TOV","Turnovers"), ("PF","Personal Fouls")]:
    sns.violinplot(y="Pos", x=stat[0], data=_10s, palette={"SG":"r", "PF":"dodgerblue","PG":"r", "SF":"dodgerblue", "C":"r"})
    plt.title(stat[1]+" per Game")
    plt.show()
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
data['3P%'].plot.hist(bins=100)

# %%
data.plot.scatter(x='Year',y="3PA")

# %%
data.plot.scatter(x='Year',y="2PA")

# %%
mymap = {'PG':1, 'SG':2, 'SF':3, 'PF':4, 'C':5}

# %%
pre90s.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
plt.rcParams["figure.figsize"] = [18,10]
sns.heatmap(data=pre90s.corr(), cmap="binary", vmin=-0.25, vmax=1)
plt.title("Correlation Heatmap")
plt.yticks(rotation=0)
plt.show()

# %%
_90s=_90s.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
plt.rcParams["figure.figsize"] = [18,10]
sns.heatmap(data=_90s.corr(), cmap="binary", vmin=-0.25, vmax=1)
plt.title("Correlation Heatmap")
plt.yticks(rotation=0)
plt.show()

# %%
_10s=_10s.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
plt.rcParams["figure.figsize"] = [18,10]
sns.heatmap(data=_10s.corr(), cmap="binary", vmin=-0.25, vmax=1)
plt.title("Correlation Heatmap")
plt.yticks(rotation=0)
plt.show()
