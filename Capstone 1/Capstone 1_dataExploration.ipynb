# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
with open('data/Seasons_Stats.csv','rb') as csvfile:
    reader1 = csv.reader(csvfile)

# %%
csvfile
# Out:
# <_io.BufferedReader name='data/Seasons_Stats.csv'>

# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('Seasons_Stats.csv')

# %%
df1['Age'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['Age'].hist()

# %%
plt.style.use('bmh')
df1['Age'].hist()

# %%
df1.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
print(df1.head())
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df1['FT%'].plot.hist(bins=50)

# %%
df1['3P%'].plot.hist(bins=50)

# %%
df1.plot.scatter(x='Age',y='FT%')

# %%
df1.plot.scatter(x='Year',y='3P%')

# %%
df1.plot.scatter(x='Year',y='3PA')

# %%
df1.plot.scatter(x='Year',y='3P')

# %%
df1.plot.scatter(x='2PA',y='3PA')

# %%
df1.plot.scatter(x='2P%',y='3P%')

# %%
df1.plot.scatter(x='Year',y='3PA',s=df1['3P%'])

# %%
df1['WS/48'].plot.hist(bins=50)

# %%
df1['PER'].plot.hist(bins = 100)

# %%
df1.plot.scatter(x='Year',y='PTS')

# %%
df1.plot.scatter(x='Year',y='AST')

# %%
df1.plot.scatter(x='Year',y='TOV')

# %%
df1.plot.scatter(x='Year',y='PF')

# %%
df1.plot.scatter(x='Year',y='STL')

# %%
df1.plot.scatter(x='Year',y='BLK')

# %%
plt.show()

# %%
y_columns = ['AST','BLK']

# %%
df1.plot(x='Year', y=y_columns)
# Out:
# /Users/yidingweng/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
print(df1['PTS'].max())
# Out:
# 4029.0

# %%
print(df1.loc['2007':'2017', 'PTS'].max())
# Out:
# 2472.0

# %%
mean = df1.mean(axis = 'columns')
mean.plot()
plt.show()

# %%
print(df1['PTS'].describe())
# Out:
# count    24624.000000
# mean       510.116350
# std        492.922981
# min          0.000000
# 25%        106.000000
# 50%        364.000000
# 75%        778.000000
# max       4029.000000
# Name: PTS, dtype: float64

# %%
print(df1['AST'].describe())
# Out:
# count    24624.000000
# mean       114.852623
# std        135.863913
# min          0.000000
# 25%         19.000000
# 50%         68.000000
# 75%        160.000000
# max       1164.000000
# Name: AST, dtype: float64

# %%
df1['PTS'].plot(kind='box')

# %%
yearly_mean = df1

# %%
powerforward = df1['Pos'] == 'PF'

# %%
powerforward.describe()
# Out:
# count     24691
# unique        2
# top       False
# freq      19725
# Name: Pos, dtype: object

# %%
center = df1['Pos'] == 'C'

# %%
center.describe()
# Out:
# count     24691
# unique        2
# top       False
# freq      19932
# Name: Pos, dtype: object

# %%
powerforward_number = powerforward.sum()

# %%
powerforward_number
# Out:
# 4966

# %%
center_number = center.sum()

# %%
center_number
# Out:
# 4759

# %%
powerforwardDF = df1[df1['Pos'] == 'PF']

# %%
powerforwardDF
# Out:
#        Unnamed: 0    Year              Player Pos   Age   Tm     G    GS  \
# 17             17  1950.0         Bob Brannum  PF  24.0  SHE  59.0   NaN
# 23             23  1950.0          Walt Budko  PF  24.0  BLB  66.0   NaN
# 41             41  1950.0        Jack Coleman  PF  25.0  ROC  68.0   NaN
# 45             45  1950.0     Dillard Crocker  PF  25.0  DNN  53.0   NaN
# 68             68  1950.0          Joe Fulks*  PF  28.0  PHW  68.0   NaN
# 92             92  1950.0        Alex Hannum*  PF  26.0  SYR  64.0   NaN
# 117           117  1950.0             Wah Wah  PF  23.0  INO  60.0   NaN
# 121           121  1950.0         Jack Kerris  PF  25.0  TOT  68.0   NaN
# 122           122  1950.0         Jack Kerris  PF  25.0  TRI   4.0   NaN
# 123           123  1950.0         Jack Kerris  PF  25.0  FTW  64.0   NaN
# 166           166  1950.0          Dick Mehen  PF  27.0  WAT  62.0   NaN
# 173           173  1950.0     Vern Mikkelsen*  PF  21.0  MNL  68.0   NaN
# ...

# %%
jamesDF = df1[df1['Player'] == 'LeBron James']

# %%
jamesDF
# Out:
#        Unnamed: 0    Year        Player Pos   Age   Tm     G    GS      MP  \
# 16746       16746  2004.0  LeBron James  SG  19.0  CLE  79.0  79.0  3122.0
# 17344       17344  2005.0  LeBron James  SF  20.0  CLE  80.0  80.0  3388.0
# 17918       17918  2006.0  LeBron James  SF  21.0  CLE  79.0  79.0  3361.0
# 18460       18460  2007.0  LeBron James  SF  22.0  CLE  78.0  78.0  3190.0
# 19017       19017  2008.0  LeBron James  SF  23.0  CLE  75.0  74.0  3027.0
# 19611       19611  2009.0  LeBron James  SF  24.0  CLE  81.0  81.0  3054.0
# 20207       20207  2010.0  LeBron James  SF  25.0  CLE  76.0  76.0  2966.0
# 20812       20812  2011.0  LeBron James  SF  26.0  MIA  79.0  79.0  3063.0
# 21395       21395  2012.0  LeBron James  SF  27.0  MIA  62.0  62.0  2326.0
# 21933       21933  2013.0  LeBron James  PF  28.0  MIA  76.0  76.0  2877.0
# 22548       22548  2014.0  LeBron James  PF  29.0  MIA  77.0  77.0  2902.0
# ...

# %%
jamesDF.plot.line(x='Year',y='PTS')

# %%
jordanDF = df1[df1['Player'] == 'Michael Jordan*']

# %%
jordanDF
# Out:
#        Unnamed: 0    Year           Player Pos   Age   Tm     G    GS      MP  \
# 7716         7716  1985.0  Michael Jordan*  SG  21.0  CHI  82.0  82.0  3144.0
# 8094         8094  1986.0  Michael Jordan*  SG  22.0  CHI  18.0   7.0   451.0
# 8469         8469  1987.0  Michael Jordan*  SG  23.0  CHI  82.0  82.0  3281.0
# 8869         8869  1988.0  Michael Jordan*  SG  24.0  CHI  82.0  82.0  3311.0
# 9297         9297  1989.0  Michael Jordan*  SG  25.0  CHI  81.0  81.0  3255.0
# 9747         9747  1990.0  Michael Jordan*  SG  26.0  CHI  82.0  82.0  3197.0
# 10212       10212  1991.0  Michael Jordan*  SG  27.0  CHI  82.0  82.0  3034.0
# 10666       10666  1992.0  Michael Jordan*  SG  28.0  CHI  80.0  80.0  3102.0
# 11106       11106  1993.0  Michael Jordan*  SG  29.0  CHI  78.0  78.0  3067.0
# 12048       12048  1995.0  Michael Jordan*  SG  31.0  CHI  17.0  17.0   668.0
# 12528       12528  1996.0  Michael Jordan*  SG  32.0  CHI  82.0  82.0  3090.0
# ...

# %%
jordanDF.plot.line(x='Year',y='PTS')

# %%
duncanDF = df1[df1['Player'] == 'Tim Duncan']

# %%
duncanDF
# Out:
#        Unnamed: 0    Year      Player Pos   Age   Tm     G    GS      MP  \
# 13551       13551  1998.0  Tim Duncan  PF  21.0  SAS  82.0  82.0  3204.0
# 14096       14096  1999.0  Tim Duncan  PF  22.0  SAS  50.0  50.0  1963.0
# 14607       14607  2000.0  Tim Duncan  PF  23.0  SAS  74.0  74.0  2875.0
# 15103       15103  2001.0  Tim Duncan  PF  24.0  SAS  82.0  82.0  3174.0
# 15643       15643  2002.0  Tim Duncan  PF  25.0  SAS  82.0  82.0  3329.0
# 16129       16129  2003.0  Tim Duncan  PF  26.0  SAS  81.0  81.0  3181.0
# 16647       16647  2004.0  Tim Duncan  PF  27.0  SAS  69.0  68.0  2527.0
# 17234       17234  2005.0  Tim Duncan  PF  28.0  SAS  66.0  66.0  2203.0
# 17806       17806  2006.0  Tim Duncan  PF  29.0  SAS  80.0  80.0  2784.0
# 18351       18351  2007.0  Tim Duncan   C  30.0  SAS  80.0  80.0  2726.0
# 18889       18889  2008.0  Tim Duncan   C  31.0  SAS  78.0  78.0  2651.0
# 19504       19504  2009.0  Tim Duncan   C  32.0  SAS  75.0  75.0  2524.0
# ...

# %%
duncanDF.plot.line(x='Year',y='PTS')

# %%
spursDF = df1[df1['Tm'] == 'SAS']

# %%
spursDF
# Out:
#        Unnamed: 0    Year                Player Pos   Age   Tm     G    GS  \
# 4684         4684  1977.0         Allan Bristow  SF  25.0  SAS  82.0   NaN
# 4699         4699  1977.0           Mack Calvin  PG  29.0  SAS  35.0   NaN
# 4717         4717  1977.0         Mike D'Antoni  SG  25.0  SAS   2.0   NaN
# 4718         4718  1977.0        Louie Dampier*  PG  32.0  SAS  80.0   NaN
# 4733         4733  1977.0         Coby Dietrick   C  28.0  SAS  82.0   NaN
# 4756         4756  1977.0             Mike Gale  SG  26.0  SAS  82.0   NaN
# 4763         4763  1977.0        George Gervin*  SF  24.0  SAS  82.0   NaN
# 4821         4821  1977.0           George Karl  PG  24.0  SAS  29.0   NaN
# 4824         4824  1977.0           Larry Kenon  PF  24.0  SAS  78.0   NaN
# 4884         4884  1977.0          Louie Nelson  SG  25.0  SAS   4.0   NaN
# 4890         4890  1977.0        Mark Olberding  PF  20.0  SAS  82.0   NaN
# ...

# %%
spursDF.reset_index()
# Out:
#      index  Unnamed: 0    Year                Player Pos   Age   Tm     G  \
# 0     4684        4684  1977.0         Allan Bristow  SF  25.0  SAS  82.0
# 1     4699        4699  1977.0           Mack Calvin  PG  29.0  SAS  35.0
# 2     4717        4717  1977.0         Mike D'Antoni  SG  25.0  SAS   2.0
# 3     4718        4718  1977.0        Louie Dampier*  PG  32.0  SAS  80.0
# 4     4733        4733  1977.0         Coby Dietrick   C  28.0  SAS  82.0
# 5     4756        4756  1977.0             Mike Gale  SG  26.0  SAS  82.0
# 6     4763        4763  1977.0        George Gervin*  SF  24.0  SAS  82.0
# 7     4821        4821  1977.0           George Karl  PG  24.0  SAS  29.0
# 8     4824        4824  1977.0           Larry Kenon  PF  24.0  SAS  78.0
# 9     4884        4884  1977.0          Louie Nelson  SG  25.0  SAS   4.0
# 10    4890        4890  1977.0        Mark Olberding  PF  20.0  SAS  82.0
# 11    4896        4896  1977.0          Billy Paultz   C  28.0  SAS  82.0
# ...

# %%
sas_points_by_player = spursDF.groupby(['Player','Year'])['PTS'].sum()
print(sas_points_by_player)
# Out:
# Player             Year
# Albert King        1989.0     327.0
# Alex Garcia        2004.0       3.0
# Alex Scales        2006.0       0.0
# Alfredrick Hughes  1986.0     356.0
# Allan Bristow      1977.0     936.0
#                    1978.0     666.0
#                    1979.0     472.0
# Alonzo Gee         2011.0       2.0
# Alvin Robertson    1985.0     726.0
#                    1986.0    1392.0
#                    1987.0    1435.0
#                    1988.0    1610.0
#                    1989.0    1122.0
# Amal McCaskill     2002.0      52.0
# Andre Miller       2016.0      56.0
# Andrew Gaze        1999.0      21.0
# Anthony Bowie      1989.0     155.0
# Anthony Carter     2004.0      22.0
# Anthony Goldwire   2003.0      12.0
# Anthony Jones      1987.0     286.0
# Anthony Tolliver   2009.0      52.0
# Antoine Carr       1992.0     881.0
#                    1993.0     932.0
#                    1994.0     198.0
# Antonio Daniels    1999.0     220.0
# ...

# %%
sas_points_by_player = sas_points_by_player.unstack(level='Player')
sas_points_by_player.plot()
plt.show()

# %%
by_team = df1.groupby('Tm')
count_by_team = by_team['Player'].count()

# %%
print(count_by_team)
# Out:
# Tm
# AND      16
# ATL     788
# BAL     144
# BLB      95
# BOS     998
# BRK      93
# BUF     120
# CAP      14
# CHA     183
# CHH     243
# CHI     795
# CHO      53
# CHP      12
# CHS      13
# CHZ      17
# CIN     198
# CLE     783
# DAL     619
# DEN     672
# DET     917
# DNN      15
# FTW     106
# GSW     757
# HOU     745
# IND     625
# INO      51
# KCK     144
# KCO      48
# LAC     567
# LAL     834
#        ...
# NOK      34
# NOP      89
# NYK    1043
# NYN      18
# OKC     163
# ORL     469
# PHI     871
# PHO     764
# PHW     164
# POR     724
# ROC      91
# SAC     527
# SAS     689
# SDC      95
# SDR      51
# SEA     606
# SFW     120
# SHE      17
# STB      14
# STL     176
# SYR     170
# TOR     402
# TOT    2123
# TRI      41
# UTA     577
# VAN      98
# WAS     351
# WAT      21
# WSB     355
# WSC      27
# Name: Player, Length: 69, dtype: int64

# %%
print(by_team['PTS'].mean())
# Out:
# Tm
# AND    349.312500
# ATL    515.507614
# BAL    642.819444
# BLB    268.410526
# BOS    569.947896
# BRK    438.956989
# BUF    579.383333
# CAP    596.642857
# CHA    415.617486
# CHH    463.514403
# CHI    529.578616
# CHO    467.943396
# CHP    600.000000
# CHS    411.692308
# CHZ    517.705882
# CIN    685.792929
# CLE    487.858238
# DAL    494.483037
# DEN    527.125000
# DET    547.637950
# DNN    321.133333
# FTW    439.641509
# GSW    523.169089
# HOU    518.244295
# IND    540.819200
# INO    426.313725
# KCK    623.131944
# KCO    531.229167
# LAC    468.273369
# LAL    598.510791
#           ...
# NOK    454.235294
# NOP    374.191011
# NYK    528.563758
# NYN    436.944444
# OKC    462.263804
# ORL    478.400853
# PHI    523.455798
# PHO    557.217277
# PHW    556.609756
# POR    548.403315
# ROC    536.967033
# SAC    498.929791
# SAS    502.464441
# SDC    565.378947
# SDR    738.921569
# SEA    579.011551
# SFW    684.625000
# SHE    300.470588
# ...

# %%
by_team_sub = by_team['PTS']
aggregated = by_team_sub.agg(['max'])
aggregated
# Out:
#         max
# Tm
# AND  1138.0
# ATL  2397.0
# BAL  2159.0
# BLB  1269.0
# BOS  2338.0
# BRK  1539.0
# BUF  2831.0
# CAP  1735.0
# CHA  1788.0
# CHH  2115.0
# CHI  3041.0
# CHO  1830.0
# CHP  2495.0
# CHS  1115.0
# CHZ  2233.0
# CIN  2480.0
# CLE  2478.0
# DAL  2330.0
# DEN  2414.0
# DET  2380.0
# DNN   987.0
# FTW  1547.0
# GSW  2450.0
# HOU  2520.0
# IND  2075.0
# INO  1496.0
# KCK  1935.0
# KCO  2719.0
# LAC  1953.0
# LAL  2832.0
# ..      ...
# NOK  1262.0
# NOP  2099.0
# NYK  2347.0
# NYN  1006.0
# OKC  2593.0
# ORL  2407.0
# PHI  2649.0
# PHO  2201.0
# PHW  4029.0
# POR  2185.0
# ROC  1174.0
# SAC  2095.0
# SAS  2585.0
# SDC  2244.0
# SDR  2350.0
# SEA  2253.0
# SFW  3586.0
# SHE   781.0
# STB  1081.0
# STL  2429.0
# SYR  1868.0
# TOR  2107.0
# TOT  2534.0
# TRI  1144.0
# UTA  2540.0
# VAN  1829.0
# WAS  2346.0
# WAT   892.0
# WSB  1942.0
# WSC   860.0
#
# [69 rows x 1 columns]

# %%
print(aggregated.loc[:, ('max')])
# Out:
# Tm
# AND    1138.0
# ATL    2397.0
# BAL    2159.0
# BLB    1269.0
# BOS    2338.0
# BRK    1539.0
# BUF    2831.0
# CAP    1735.0
# CHA    1788.0
# CHH    2115.0
# CHI    3041.0
# CHO    1830.0
# CHP    2495.0
# CHS    1115.0
# CHZ    2233.0
# CIN    2480.0
# CLE    2478.0
# DAL    2330.0
# DEN    2414.0
# DET    2380.0
# DNN     987.0
# FTW    1547.0
# GSW    2450.0
# HOU    2520.0
# IND    2075.0
# INO    1496.0
# KCK    1935.0
# KCO    2719.0
# LAC    1953.0
# LAL    2832.0
#         ...
# NOK    1262.0
# NOP    2099.0
# NYK    2347.0
# NYN    1006.0
# OKC    2593.0
# ORL    2407.0
# PHI    2649.0
# PHO    2201.0
# PHW    4029.0
# POR    2185.0
# ROC    1174.0
# SAC    2095.0
# SAS    2585.0
# SDC    2244.0
# SDR    2350.0
# SEA    2253.0
# SFW    3586.0
# SHE     781.0
# STB    1081.0
# STL    2429.0
# SYR    1868.0
# TOR    2107.0
# TOT    2534.0
# TRI    1144.0
# UTA    2540.0
# VAN    1829.0
# WAS    2346.0
# WAT     892.0
# WSB    1942.0
# WSC     860.0
# ...

# %%
by_team_Player = df1.groupby(['Tm','Player'])

# %%
count_team_Player = by_team_Player['PTS'].count()

# %%
print(count_team_Player)
# Out:
# Tm   Player
# AND  Bill Closs          1
#      Charlie Black       1
#      Ed Stanczak         1
#      Frank Gates         1
#      Frankie Brian       1
#      Howie Schultz       1
#      Jack Smiley         1
#      Jake Carter         1
#      John Hargis         1
#      Milo Komenich       1
#      Murray Mitchell     1
#      Ralph Johnson       1
#      Red Owens           1
#      Richie Niemiera     1
#      Rollie Seltz        1
#      Walt Kirk           1
# ATL  Acie Law            2
#      Adam Keefe          2
#      Adreian Payne       1
#      Al Harrington       2
#      Al Horford          9
#      Al Wood             1
#      Alan Henderson      9
#      Alex Stivrins       1
#      Alexander Volkov    2
#      Amal McCaskill      1
#      Andre Spencer       1
#      Andrew Lang         3
#      Andy Panko          1
#      Anthony Grundy      1
#                         ..
# WSB  Tom Kozelko         2
#      Tom Kropp           1
#      Tom McMillen        3
# ...

# %%
counted = df1.pivot_table(index='Tm', values='PTS', columns='Year', aggfunc='sum')
counted['totals'] = counted.sum(axis='columns')
counted = counted.sort_values('totals', ascending=False)
print(counted.head(15))
# Out:
# Year   1950.0  1951.0  1952.0  1953.0  1954.0  1955.0  1956.0  1957.0  1958.0  \
# Tm
# TOT   13756.0  9791.0  3891.0  7074.0  4613.0  4254.0  2812.0  3090.0  1670.0
# BOS    5420.0  5604.0  6027.0  6258.0  5961.0  7304.0  7632.0  7599.0  7916.0
# NYK    5488.0  5666.0  5609.0  5985.0  5688.0  6611.0  7212.0  7253.0  8068.0
# DET       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  7585.0
# LAL       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PHI       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PHO       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHI       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MIL       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ATL       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# POR       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
twentyFirstCentry = (df1.Year >= 2000) & (df1.Year <= 2017)
is_sas_lal = df1.Tm.isin(['SAS', 'LAL'])
sas_lal_21 = df1.loc[twentyFirstCentry & is_sas_lal]
team_grouped = sas_lal_21.groupby('Tm')

# %%
NPlayers = team_grouped['Player'].nunique().sort_values(ascending=False)

# %%
NPlayers
# Out:
# Tm
# SAS    137
# LAL    133
# Name: Player, dtype: int64
